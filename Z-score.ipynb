# %%
import pandas as pd
from scipy.stats import zscore

data = [120,122,121,119,118,500]

df = pd.DataFrame(data, columns=['value'])

df['z_score'] = zscore(df['value'])

print(df)

result = zscore(data)
print("Data:", data)
print("Z-scores:", result)
# Out:
#    value   z_score
# 0    120 -0.447195
# 1    122 -0.433073
# 2    121 -0.440134
# 3    119 -0.454256
# 4    118 -0.461317
# 5    500  2.235975
# Data: [120, 122, 121, 119, 118, 500]
# Z-scores: [-0.44719501 -0.43307307 -0.44013404 -0.45425599 -0.46131696  2.23597507]
