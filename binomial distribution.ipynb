# %%
import matplotlib.pyplot as plt
from scipy.stats  import binom
import numpy as np
n=12
p=0.7
k=10
prob=binom.pmf(k,n,p)#shows highest possibilty is 0.06  which means 60% chance for sucess
print(prob)
# Out:
# 0.16779029790600017

# %%
x = np.arange(0, n + 1)
pmf_values = binom.pmf(x, n, p)
plt.bar(x, pmf_values, color="skyblue", edgecolor="black", label="Binomial PMF")

# highlight k = 10
plt.bar(k, prob, color="yellow", edgecolor="black", label=f"k = {k}")

plt.xlabel("Number of successes")
plt.ylabel("Probability")
plt.title(f"Binomial distribution")
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.show()

# %%
from scipy.stats import binom
n=12
p=0.9
k=10
p=binom.cdf(k,n,p)
print(p)
# Out:
# 0.3409977482109998
