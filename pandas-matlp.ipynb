# %%
import pandas as pd
data = {
    "Name": ["Ramesh", "Sanmugan", "Ravikumar"],
    "Age": [30, 25, 29],
    "Marks": [95, 100, 80]
}

df = pd.DataFrame(data)
df.to_csv("data.csv")
print(df)
# Out:
#         Name  Age  Marks
# 0     Ramesh   30     95
# 1   Sanmugan   25    100
# 2  Ravikumar   29     80

# %%
#view dataset

df = pd.read_csv("data.csv")

print(df.head())
# Out:
#    Unnamed: 0       Name  Age  Marks
# 0           0     Ramesh   30     95
# 1           1   Sanmugan   25    100
# 2           2  Ravikumar   29     80

# %%
print(df.tail())
# Out:
#    Unnamed: 0       Name  Age  Marks
# 0           0     Ramesh   30     95
# 1           1   Sanmugan   25    100
# 2           2  Ravikumar   29     80

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3 non-null      int64
#  1   Name        3 non-null      object
#  2   Age         3 non-null      int64
#  3   Marks       3 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 156.0+ bytes
# None

# %%
print(df.describe())
# Out:
#        Unnamed: 0        Age       Marks
# count         3.0   3.000000    3.000000
# mean          1.0  28.000000   91.666667
# std           1.0   2.645751   10.408330
# min           0.0  25.000000   80.000000
# 25%           0.5  27.000000   87.500000
# 50%           1.0  29.000000   95.000000
# 75%           1.5  29.500000   97.500000
# max           2.0  30.000000  100.000000

# %%
print(df[df["Marks"] > 85])
# Out:
#    Unnamed: 0      Name  Age  Marks
# 0           0    Ramesh   30     95
# 1           1  Sanmugan   25    100

# %%
df["Result"] = ["Pass", "Pass", "Pass"]

print(df)
# Out:
#    Unnamed: 0       Name  Age  Marks Result
# 0           0     Ramesh   30     95   Pass
# 1           1   Sanmugan   25    100   Pass
# 2           2  Ravikumar   29     80   Pass

# %%
data = {
    "Department": ["HR", "IT", "HR", "IT"],
    "Salary": [50000, 60000, 55000, 65000]
}

df = pd.DataFrame(data)

print(df.groupby("Department").mean())
# Out:
#              Salary
# Department
# HR          52500.0
# IT          62500.0

# %%
import pandas as pd

data = {
    "Name": ["Ramesh", "Sam", "Vishnu"]
}

df = pd.DataFrame(data)

df["Department"] = ["IT", "CSE", "EEE"]

print(df)
# Out:
#      Name Department
# 0  Ramesh         IT
# 1     Sam        CSE
# 2  Vishnu        EEE

# %%
import pandas as pd

data = {
    "Name": ["Ram", None, "Ravi"],
    "City": ["salem", "Bommidi", None]
}

df = pd.DataFrame(data)

df = df.fillna("Unknown")

print(df)
# Out:
#       Name     City
# 0      Ram    salem
# 1  Unknown  Bommidi
# 2     Ravi  Unknown

# %%
df["City"] = df["City"].fillna("Not Available")
df
# Out:
#       Name     City
# 0      Ram    salem
# 1  Unknown  Bommidi
# 2     Ravi  Unknown

# %%
data = {
    "Name": ["Ram", "", "Ravi"],
    "City": ["Chennai", "Bommidi", ""]
}

df = pd.DataFrame(data)

df = df.replace("", "Unknown")

print(df)
# Out:
#       Name     City
# 0      Ram  Chennai
# 1  Unknown  Bommidi
# 2     Ravi  Unknown
